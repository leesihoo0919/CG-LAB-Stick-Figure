# %%
import os
import cv2
from matplotlib import pyplot as plt
import torch
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
#GPU

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
## Stick Figure CNN Model + Distance Transform

# 이미지 데이터(특징값) 불러오는 함수 -> 전처리 동시에

# 이미지 데이터(특징값) 불러오는 함수 -> 전처리 동시에
def load_images(image_path, y_train=None):
    images = []
    for filename in os.listdir(image_path):
        if y_train is not None:
            if  (filename in y_train) is False:
                continue
        img = cv2.imread(os.path.join(image_path,filename), cv2.IMREAD_GRAYSCALE)
        if img is not None:
            _, binary_image = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)
            binary_image = binary_image.astype(np.uint8)  # 이미지 형식 변환
            distance_transform = cv2.distanceTransform(binary_image, cv2.DIST_L2, 5)
            img = cv2.resize(distance_transform, (32, 32)) # 이미지 크기 조정
            img = img.flatten() # 이미지 일차원 배열로 변환
            images.append(img)
    return np.array(images)


# CSV(목푯값) 불러오는 함수 -> 첫 번째 열(이미지 이름) 제외
def load_csv(csv_path):
    df = pd.read_csv(csv_path, header=None)
    joint = df.iloc[:, 1:].to_numpy()
    return joint

#
def load_csv_first_col(csv_path):
    df = pd.read_csv(csv_path, header=None)
    joint = df.iloc[:, 0:1].to_numpy().flatten()
    return joint

# Load image and target data
X_train = load_images("./image_train/", load_csv_first_col("./joint_train.csv"))
y_train = load_csv("./joint_train.csv")

for i in range(len(y_train)):
    if y_train[i][6] > y_train[i][10]:
        for j in range(6,10):
            tmp = y_train[i][j]
            y_train[i][j] = y_train[i][j+4]
            y_train[i][j+4] = tmp

    if y_train[i][14] > y_train[i][18]:
        for j in range(14,18):
            tmp = y_train[i][j]
            y_train[i][j] = y_train[i][j+4]
            y_train[i][j+4] = tmp

        

X_validation = load_images("./image_validation/")
y_validation = load_csv("./joint_validation.csv")


for i in range(len(y_validation)):
    if y_validation[i][6] > y_validation[i][10]:
        for j in range(6,10):
            tmp = y_validation[i][j]
            y_validation[i][j] = y_validation[i][j+4]
            y_validation[i][j+4] = tmp

    if y_validation[i][14] > y_validation[i][18]:
        for j in range(14,18):
            tmp = y_validation[i][j]
            y_validation[i][j] = y_validation[i][j+4]
            y_validation[i][j+4] = tmp

X_test = load_images("./image_test/")
y_test = load_csv("./joint_test.csv")

for i in range(len(y_test)):
    if y_test[i][6] > y_test[i][10]:
        for j in range(6,10):
            tmp = y_test[i][j]
            y_test[i][j] = y_test[i][j+4]
            y_test[i][j+4] = tmp

    if y_test[i][14] > y_test[i][18]:
        for j in range(14,18):
            tmp = y_test[i][j]
            y_test[i][j] = y_test[i][j+4]
            y_test[i][j+4] = tmp

X_ex = load_images("./image_ex/")
y_ex = load_csv("./joint_ex.csv")

for i in range(len(y_ex)):
    if y_ex[i][6] > y_ex[i][10]:
        for j in range(6,10):
            tmp = y_ex[i][j]
            y_ex[i][j] = y_ex[i][j+4]
            y_ex[i][j+4] = tmp

    if y_ex[i][14] > y_ex[i][18]:
        for j in range(14,18):
            tmp = y_ex[i][j]
            y_ex[i][j] = y_ex[i][j+4]
            y_ex[i][j+4] = tmp



# 데이터 전처리 (입력 이미지와 목표값 간의 매핑 필요)
x_train_preprocessed = X_train.reshape(-1, 32, 32, 1).astype('float32') / 255.0
x_validation_preprocessed = X_validation.reshape(-1, 32, 32, 1).astype('float32') / 255.0
x_test_preprocessed = X_test.reshape(-1, 32, 32, 1).astype('float32') / 255.0
x_ex_preprocessed = X_ex.reshape(-1, 32, 32, 1).astype('float32') / 255.0




# to device
x_train_preprocessed = torch.FloatTensor(x_train_preprocessed).to(device)
x_validation_preprocessed = torch.FloatTensor(x_validation_preprocessed).to(device)
x_test_preprocessed = torch.FloatTensor(x_test_preprocessed).to(device)
x_ex_preprocessed = torch.FloatTensor(x_ex_preprocessed).to(device)


# transpose (batch, H, W, C) -> (batch, C, H, W)
x_train_preprocessed = x_train_preprocessed.transpose(1, 3)
x_validation_preprocessed = x_validation_preprocessed.transpose(1, 3)
x_test_preprocessed = x_test_preprocessed.transpose(1, 3)
x_ex_preprocessed = x_ex_preprocessed.transpose(1, 3)

y_train = torch.FloatTensor(y_train).to(device)
y_validation = torch.FloatTensor(y_validation).to(device)
y_test = torch.FloatTensor(y_test).to(device)
y_ex = torch.FloatTensor(y_ex).to(device)


print(x_train_preprocessed.shape)
print(y_train.shape)
print(x_validation_preprocessed.shape)
print(y_validation.shape)
print(x_test_preprocessed.shape)
print(y_test.shape)
print(x_ex_preprocessed.shape)
print(y_ex.shape)


# dataset
train_dataset = torch.utils.data.TensorDataset(x_train_preprocessed, y_train)
validation_dataset = torch.utils.data.TensorDataset(x_validation_preprocessed, y_validation)
test_dataset = torch.utils.data.TensorDataset(x_test_preprocessed, y_test)
ex_dataset = torch.utils.data.TensorDataset(x_ex_preprocessed, y_ex)


# batch size
batch_size = 64

# dataloader
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
validation_loader = torch.utils.data.DataLoader(validation_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=True)
# Out:
# torch.Size([15330, 1, 32, 32])
# torch.Size([15330, 22])
# torch.Size([4000, 1, 32, 32])
# torch.Size([4000, 22])
# torch.Size([4000, 1, 32, 32])
# torch.Size([4000, 22])
# torch.Size([1, 1, 32, 32])
# torch.Size([1, 22])

# %%
# model by keras
# model = tf.keras.Sequential()
# model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 1)))
# model.add(layers.MaxPooling2D((2, 2)))
# model.add(layers.Conv2D(64, (3, 3), activation='relu'))
# model.add(layers.MaxPooling2D((2, 2)))
# model.add(layers.Conv2D(128, (3, 3), activation='relu'))
# model.add(layers.Flatten())
# model.add(layers.Dense(64, activation='relu'))
# model.add(layers.Dense(22)) 
# model.compile(optimizer='adam',
#               loss='mse',
#               metrics=['mae'])
# history = model.fit(x_train_preprocessed, y_train, epochs=1000, batch_size=32, validation_data=(x_validation_preprocessed, y_validation))
#X_train.shape

##레이어 수정
# a cnn sequential model by pytorch
class SK_CNN(nn.Module):

    def __init__(self):
        super(SK_CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=1)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.fc1 = nn.Linear(128 * 8 * 8, 128)
        self.fc2 = nn.Linear(128, 22)

    def forward(self, x):
        x = self.pool1(nn.functional.relu(self.conv1(x)))
        x = self.pool2(nn.functional.relu(self.conv2(x)))
        x = nn.functional.relu(self.conv3(x))
        x = x.view(-1, 128 * 8 * 8)
        x = nn.functional.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
SAVE_DIR = './model_save'

model = SK_CNN()
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.MSELoss()

# to cuda
model = model.to(device)
criterion = criterion.to(device)

epoch = 1000

# train
history = {'loss': [], 'val_loss': []}
model.train()
train_loss = 0
for epoch_idx in range(epoch):
    for x_batch, y_batch in train_loader:
        optimizer.zero_grad()
        y_pred = model(x_batch)
        loss = criterion(y_pred, y_batch)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    train_loss /= len(train_loader.dataset)
    history['loss'].append(train_loss)
    if epoch_idx % 10 == 0:
        train_r2_score = r2_score(y_batch.detach().cpu().numpy(), y_pred.detach().cpu().numpy())
        print('Epoch: {}, Train Loss: {:.4f}, R2 {:.4f}'.format(epoch_idx, train_loss, train_r2_score))

    # validation
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for x_batch, y_batch in validation_loader:
            y_pred = model(x_batch)
            loss = criterion(y_pred, y_batch)
            val_loss += loss.item()
        val_loss /= len(validation_loader.dataset)
        history['val_loss'].append(val_loss)
        if epoch_idx % 10 == 0:
            val_r2_score = r2_score(y_batch.detach().cpu(), y_pred.detach().cpu())
            print('Epoch: {}, Validation Loss: {:.4f}, R2 {:4f}'.format(epoch_idx, val_loss, val_r2_score))
# Out:
# Epoch: 0, Train Loss: 52.7683, R2 -0.0550
# Epoch: 0, Validation Loss: 14.8349, R2 -0.154413
# Epoch: 10, Train Loss: 9.2915, R2 0.5085
# Epoch: 10, Validation Loss: 5.1100, R2 0.487507
# Epoch: 20, Train Loss: 5.6123, R2 0.8249
# Epoch: 20, Validation Loss: 4.0735, R2 0.615375
# Epoch: 30, Train Loss: 3.7582, R2 0.8983
# Epoch: 30, Validation Loss: 2.9801, R2 0.749653
# Epoch: 40, Train Loss: 2.6166, R2 0.8804
# Epoch: 40, Validation Loss: 2.5522, R2 0.812439
# Epoch: 50, Train Loss: 1.9181, R2 0.8987
# Epoch: 50, Validation Loss: 2.4106, R2 0.658543
# Epoch: 60, Train Loss: 1.4914, R2 0.9354
# Epoch: 60, Validation Loss: 2.1623, R2 0.716596
# Epoch: 70, Train Loss: 1.2435, R2 0.9434
# Epoch: 70, Validation Loss: 1.9516, R2 0.800877
# Epoch: 80, Train Loss: 1.0744, R2 0.9499
# Epoch: 80, Validation Loss: 1.9408, R2 0.808807
# Epoch: 90, Train Loss: 0.9156, R2 0.9523
# Epoch: 90, Validation Loss: 1.8456, R2 0.880780
# Epoch: 100, Train Loss: 0.8367, R2 0.9653
# Epoch: 100, Validation Loss: 1.8777, R2 0.817870
# Epoch: 110, Train Loss: 0.7522, R2 0.9488
# Epoch: 110, Validation Loss: 1.7741, R2 0.890068
# Epoch: 120, Train Loss: 0.6837, R2 0.9684
# Epoch: 120, Validation Loss: 1.7726, R2 0.825182
# Epoch: 130, Train Loss: 0.6328, R2 0.9755
# Epoch: 130, Validation Loss: 1.8008, R2 0.863896
# Epoch: 140, Train Loss: 0.5835, R2 0.9796
# Epoch: 140, Validation Loss: 1.6889, R2 0.872508
# Epoch: 150, Train Loss: 0.5571, R2 0.9768
# Epoch: 150, Validation Loss: 1.6631, R2 0.830587
# Epoch: 160, Train Loss: 0.5110, R2 0.9717
# Epoch: 160, Validation Loss: 1.7945, R2 0.775551
# Epoch: 170, Train Loss: 0.4867, R2 0.9760
# Epoch: 170, Validation Loss: 1.6458, R2 0.821477
# Epoch: 180, Train Loss: 0.4537, R2 0.9842
# Epoch: 180, Validation Loss: 1.6142, R2 0.789075
# Epoch: 190, Train Loss: 0.4285, R2 0.9804
# Epoch: 190, Validation Loss: 1.6403, R2 0.857090
# Epoch: 200, Train Loss: 0.4156, R2 0.9819
# Epoch: 200, Validation Loss: 1.6224, R2 0.786327
# Epoch: 210, Train Loss: 0.3932, R2 0.9818
# Epoch: 210, Validation Loss: 1.5737, R2 0.825437
# Epoch: 220, Train Loss: 0.3855, R2 0.9739
# Epoch: 220, Validation Loss: 1.5794, R2 0.890039
# Epoch: 230, Train Loss: 0.3679, R2 0.9730
# Epoch: 230, Validation Loss: 1.5941, R2 0.786164
# Epoch: 240, Train Loss: 0.3440, R2 0.9842
# Epoch: 240, Validation Loss: 1.5613, R2 0.803985
# Epoch: 250, Train Loss: 0.3357, R2 0.9832
# Epoch: 250, Validation Loss: 1.5721, R2 0.812972
# Epoch: 260, Train Loss: 0.3349, R2 0.9814
# Epoch: 260, Validation Loss: 1.5716, R2 0.849900
# Epoch: 270, Train Loss: 0.3105, R2 0.9875
# Epoch: 270, Validation Loss: 1.5019, R2 0.882675
# Epoch: 280, Train Loss: 0.3096, R2 0.9882
# Epoch: 280, Validation Loss: 1.5452, R2 0.828810
# Epoch: 290, Train Loss: 0.2953, R2 0.9862
# Epoch: 290, Validation Loss: 1.5661, R2 0.905408
# Epoch: 300, Train Loss: 0.2848, R2 0.9880
# Epoch: 300, Validation Loss: 1.5441, R2 0.885488
# Epoch: 310, Train Loss: 0.2705, R2 0.9883
# Epoch: 310, Validation Loss: 1.5471, R2 0.857900
# Epoch: 320, Train Loss: 0.2658, R2 0.9877
# Epoch: 320, Validation Loss: 1.5033, R2 0.906508
# Epoch: 330, Train Loss: 0.2634, R2 0.9855
# Epoch: 330, Validation Loss: 1.5170, R2 0.933715
# Epoch: 340, Train Loss: 0.2562, R2 0.9874
# Epoch: 340, Validation Loss: 1.4995, R2 0.917652
# Epoch: 350, Train Loss: 0.2533, R2 0.9874
# Epoch: 350, Validation Loss: 1.5101, R2 0.893624
# Epoch: 360, Train Loss: 0.2441, R2 0.9861
# Epoch: 360, Validation Loss: 1.5272, R2 0.912632
# Epoch: 370, Train Loss: 0.2373, R2 0.9849
# Epoch: 370, Validation Loss: 1.5105, R2 0.692538
# Epoch: 380, Train Loss: 0.2269, R2 0.9868
# Epoch: 380, Validation Loss: 1.4982, R2 0.816977
# Epoch: 390, Train Loss: 0.2218, R2 0.9900
# Epoch: 390, Validation Loss: 1.4648, R2 0.803409
# Epoch: 400, Train Loss: 0.2207, R2 0.9919
# Epoch: 400, Validation Loss: 1.4960, R2 0.897449
# Epoch: 410, Train Loss: 0.2158, R2 0.9874
# Epoch: 410, Validation Loss: 1.5285, R2 0.891964
# Epoch: 420, Train Loss: 0.2170, R2 0.9890
# Epoch: 420, Validation Loss: 1.4782, R2 0.902201
# Epoch: 430, Train Loss: 0.2008, R2 0.9917
# Epoch: 430, Validation Loss: 1.4747, R2 0.917411
# Epoch: 440, Train Loss: 0.2049, R2 0.9913
# Epoch: 440, Validation Loss: 1.4432, R2 0.913342
# Epoch: 450, Train Loss: 0.2046, R2 0.9905
# Epoch: 450, Validation Loss: 1.4608, R2 0.850945
# Epoch: 460, Train Loss: 0.1940, R2 0.9893
# Epoch: 460, Validation Loss: 1.4578, R2 0.903849
# Epoch: 470, Train Loss: 0.1988, R2 0.9899
# Epoch: 470, Validation Loss: 1.4883, R2 0.908675
# Epoch: 480, Train Loss: 0.1866, R2 0.9903
# Epoch: 480, Validation Loss: 1.4546, R2 0.880169
# Epoch: 490, Train Loss: 0.1883, R2 0.9913
# Epoch: 490, Validation Loss: 1.4658, R2 0.890099
# Epoch: 500, Train Loss: 0.1790, R2 0.9916
# Epoch: 500, Validation Loss: 1.4479, R2 0.821236
# Epoch: 510, Train Loss: 0.1790, R2 0.9897
# Epoch: 510, Validation Loss: 1.4926, R2 0.739080
# Epoch: 520, Train Loss: 0.1791, R2 0.9929
# Epoch: 520, Validation Loss: 1.4645, R2 0.843784
# Epoch: 530, Train Loss: 0.1781, R2 0.9890
# Epoch: 530, Validation Loss: 1.4562, R2 0.779593
# Epoch: 540, Train Loss: 0.1706, R2 0.9928
# Epoch: 540, Validation Loss: 1.4403, R2 0.878015
# Epoch: 550, Train Loss: 0.1660, R2 0.9917
# Epoch: 550, Validation Loss: 1.4509, R2 0.607580
# Epoch: 560, Train Loss: 0.1683, R2 0.9928
# Epoch: 560, Validation Loss: 1.4556, R2 0.905132
# Epoch: 570, Train Loss: 0.1614, R2 0.9905
# Epoch: 570, Validation Loss: 1.4328, R2 0.848148
# Epoch: 580, Train Loss: 0.1590, R2 0.9935
# Epoch: 580, Validation Loss: 1.4572, R2 0.808155
# Epoch: 590, Train Loss: 0.1565, R2 0.9896
# Epoch: 590, Validation Loss: 1.4270, R2 0.832023
# Epoch: 600, Train Loss: 0.1542, R2 0.9925
# Epoch: 600, Validation Loss: 1.4927, R2 0.903295
# Epoch: 610, Train Loss: 0.1534, R2 0.9894
# Epoch: 610, Validation Loss: 1.4627, R2 0.798533
# Epoch: 620, Train Loss: 0.1500, R2 0.9919
# Epoch: 620, Validation Loss: 1.4649, R2 0.865930
# Epoch: 630, Train Loss: 0.1494, R2 0.9910
# Epoch: 630, Validation Loss: 1.4291, R2 0.830707
# Epoch: 640, Train Loss: 0.1472, R2 0.9945
# Epoch: 640, Validation Loss: 1.4545, R2 0.812128
# Epoch: 650, Train Loss: 0.1425, R2 0.9907
# Epoch: 650, Validation Loss: 1.4460, R2 0.846563
# Epoch: 660, Train Loss: 0.1474, R2 0.9940
# Epoch: 660, Validation Loss: 1.4344, R2 0.936792
# Epoch: 670, Train Loss: 0.1389, R2 0.9917
# Epoch: 670, Validation Loss: 1.4655, R2 0.900363
# Epoch: 680, Train Loss: 0.1404, R2 0.9931
# Epoch: 680, Validation Loss: 1.4232, R2 0.916830
# Epoch: 690, Train Loss: 0.1392, R2 0.9918
# Epoch: 690, Validation Loss: 1.4433, R2 0.827196
# Epoch: 700, Train Loss: 0.1357, R2 0.9918
# Epoch: 700, Validation Loss: 1.4371, R2 0.855938
# Epoch: 710, Train Loss: 0.1333, R2 0.9960
# Epoch: 710, Validation Loss: 1.4357, R2 0.920815
# Epoch: 720, Train Loss: 0.1291, R2 0.9922
# Epoch: 720, Validation Loss: 1.4367, R2 0.859188
# Epoch: 730, Train Loss: 0.1306, R2 0.9935
# Epoch: 730, Validation Loss: 1.4498, R2 0.809224
# Epoch: 740, Train Loss: 0.1327, R2 0.9929
# Epoch: 740, Validation Loss: 1.4682, R2 0.879824
# Epoch: 750, Train Loss: 0.1285, R2 0.9933
# Epoch: 750, Validation Loss: 1.4562, R2 0.884152
# Epoch: 760, Train Loss: 0.1244, R2 0.9929
# Epoch: 760, Validation Loss: 1.4184, R2 0.908201
# Epoch: 770, Train Loss: 0.1287, R2 0.9936
# Epoch: 770, Validation Loss: 1.4401, R2 0.914671
# Epoch: 780, Train Loss: 0.1213, R2 0.9942
# Epoch: 780, Validation Loss: 1.4306, R2 0.874610
# Epoch: 790, Train Loss: 0.1227, R2 0.9946
# Epoch: 790, Validation Loss: 1.4334, R2 0.856407
# Epoch: 800, Train Loss: 0.1235, R2 0.9951
# Epoch: 800, Validation Loss: 1.4277, R2 0.850018
# Epoch: 810, Train Loss: 0.1280, R2 0.9935
# Epoch: 810, Validation Loss: 1.4415, R2 0.888407
# Epoch: 820, Train Loss: 0.1179, R2 0.9941
# Epoch: 820, Validation Loss: 1.4460, R2 0.813512
# Epoch: 830, Train Loss: 0.1167, R2 0.9927
# Epoch: 830, Validation Loss: 1.4421, R2 0.796888
# Epoch: 840, Train Loss: 0.1260, R2 0.9938
# Epoch: 840, Validation Loss: 1.4434, R2 0.878597
# Epoch: 850, Train Loss: 0.1172, R2 0.9953
# Epoch: 850, Validation Loss: 1.4432, R2 0.919063
# Epoch: 860, Train Loss: 0.1164, R2 0.9930
# Epoch: 860, Validation Loss: 1.4426, R2 0.840919
# Epoch: 870, Train Loss: 0.1153, R2 0.9926
# Epoch: 870, Validation Loss: 1.4532, R2 0.842770
# Epoch: 880, Train Loss: 0.1205, R2 0.9960
# Epoch: 880, Validation Loss: 1.4135, R2 0.877961
# Epoch: 890, Train Loss: 0.1103, R2 0.9959
# Epoch: 890, Validation Loss: 1.4377, R2 0.758503
# Epoch: 900, Train Loss: 0.1110, R2 0.9933
# Epoch: 900, Validation Loss: 1.4280, R2 0.906891
# Epoch: 910, Train Loss: 0.1167, R2 0.9936
# Epoch: 910, Validation Loss: 1.4453, R2 0.893284
# Epoch: 920, Train Loss: 0.1117, R2 0.9947
# Epoch: 920, Validation Loss: 1.4225, R2 0.965512
# Epoch: 930, Train Loss: 0.1098, R2 0.9946
# Epoch: 930, Validation Loss: 1.4374, R2 0.878107
# Epoch: 940, Train Loss: 0.1105, R2 0.9951
# Epoch: 940, Validation Loss: 1.4278, R2 0.842134
# Epoch: 950, Train Loss: 0.1053, R2 0.9945
# Epoch: 950, Validation Loss: 1.4198, R2 0.930845
# Epoch: 960, Train Loss: 0.1043, R2 0.9947
# Epoch: 960, Validation Loss: 1.4219, R2 0.949430
# Epoch: 970, Train Loss: 0.1041, R2 0.9953
# Epoch: 970, Validation Loss: 1.4634, R2 0.894710
# Epoch: 980, Train Loss: 0.1073, R2 0.9951
# Epoch: 980, Validation Loss: 1.4255, R2 0.956769
# Epoch: 990, Train Loss: 0.1014, R2 0.9941
# Epoch: 990, Validation Loss: 1.4423, R2 0.885895

# %%
# validation
model.eval()
validation_loss = 0
with torch.no_grad():
    for data, target in validation_loader:
        output = model(data)
        validation_loss += criterion(output, target).item()
    validation_loss /= len(validation_loader.dataset)
    validation_r2_score = r2_score(target.cpu().detach().numpy(), output.cpu().detach().numpy())
    print(('\nValidation set: Average loss: {:.4f}, R2 score:{:.4f}\n').format(validation_loss, validation_r2_score))

# test 
model.eval()
test_loss = 0
with torch.no_grad():
    for data, target in test_loader:
        output = model(data)
        test_loss += criterion(output, target).item()
    test_loss /= len(test_loader.dataset)
    test_r2_score = r2_score(target.cpu().detach().numpy(), output.cpu().detach().numpy())
    print(('\nTest set: Average loss: {:.4f}, R2 score:{:.4f}\n').format(test_loss, test_r2_score))
# Out:
# Validation set: Average loss: 1.4440, R2 score:0.9236
#
#
# Test set: Average loss: 1.1289, R2 score:0.7384

# %%
X_ex = load_images("./image_ex/")
y_ex = load_csv("./joint_ex.csv")

# 손실값 기록
loss = history['loss']
val_loss = history['val_loss']

# # 지표 기록
# mae = history['mae']
# val_mae = history.history['val_mae']

# 시각화 

import matplotlib.pyplot as plt



# 손실값 그래프
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
X_ex = load_images("./image_ex/")
x_ex_preprocessed = X_ex.reshape(-1, 32, 32, 1).astype('float32') / 255.0
x_ex_preprocessed = torch.FloatTensor(x_ex_preprocessed).to(device)
x_ex_preprocessed = x_ex_preprocessed.transpose(1, 3)
imageFile = './image_ex/ccc.png'
X_ex_image = cv2.imread(imageFile)

# 각 관절 위치 값 저장
# data=predictions[0]
data=model(x_ex_preprocessed[0].unsqueeze(0)).squeeze(0).cpu().detach().numpy()

c1_x = int(round(data[0]))           
c1_y = int(round(data[1]))            
c2_x = int(round(data[2]))             
c2_y = int(round(data[3]))             
c3_x = int(round(data[4]))             
c3_y = int(round(data[5]))             
le_x = int(round(data[6]))             
le_y = int(round(data[7]))            
lh_x = int(round(data[8]))             
lh_y = int(round(data[9]))             
re_x = int(round(data[10]))             
re_y = int(round(data[11]))             
rh_x = int(round(data[12]))             
rh_y = int(round(data[13]))             
lk_x = int(round(data[14]))             
lk_y = int(round(data[15]))              
lf_x = int(round(data[16]))             
lf_y = int(round(data[17]))             
rk_x = int(round(data[18]))             
rk_y = int(round(data[19]))             
rf_x = int(round(data[20]))             
rf_y = int(round(data[21]))  



cv2.circle(X_ex_image,(c1_x,c1_y), radius=5, color=(0,0,255), thickness=-1)  #빨
cv2.circle(X_ex_image,(c2_x,c2_y), radius=5, color=(0,94,255), thickness=-1)  #주
cv2.circle(X_ex_image,(c3_x,c3_y), radius=5, color=(0,228,255), thickness=-1) #노
cv2.circle(X_ex_image,(le_x,le_y), radius=5, color=(0,255,0), thickness=-1)  #초
cv2.circle(X_ex_image,(lh_x,lh_y), radius=5, color=(255,0,0), thickness=-1)  #파
cv2.circle(X_ex_image,(re_x,re_y), radius=5, color=(255,0,95), thickness=-1)
cv2.circle(X_ex_image,(rh_x,rh_y), radius=5, color=(128,0,128), thickness=-1)
cv2.circle(X_ex_image,(lk_x,lk_y), radius=5, color=(255,0,255), thickness=-1)
cv2.circle(X_ex_image,(lf_x,lf_y), radius=5, color=(128,128,128), thickness=-1)
cv2.circle(X_ex_image,(rk_x,rk_y), radius=5, color=(0,128,128), thickness=-1)
cv2.circle(X_ex_image,(rf_x,rf_y), radius=5, color=(128,128,0), thickness=-1)


img = cv2.cvtColor(X_ex_image, cv2.COLOR_BGR2RGB)

#이미지, 점 출력
plt.imshow(img)
plt.show()
